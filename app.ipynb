# %%
# !pip install streamlit
import streamlit as st
import pandas as pd
import joblib

# %%
import streamlit as st
import pandas as pd
import joblib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import joblib
model = joblib.load("/content/drive/MyDrive/Colab Notebooks/extra_trees_credit_model.pkl")

# %%
model = joblib.load("/content/drive/MyDrive/Colab Notebooks/extra_trees_credit_model.pkl")

# %%
encoders = {col: joblib.load(f"/content/drive/MyDrive/Colab Notebooks/{col}_encoder.pkl")
    for col in ['Sex', 'Housing', 'Saving accounts', 'Checking account', 'Purpose']}

# %%
st.title("Credit Risk Prediction App")
# Out:
# 2026-01-31 14:42:49.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:42:49.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:42:49.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.write ("Enter applicant information to predict credit risk")
# Out:
# 2026-01-31 14:43:21.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:43:21.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:43:21.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
age= st.number_input("Enter age", min_value=18, max_value=100, value=30)
sex= st.selectbox("Enter sex", ["Male", "Female"])
job= st.number_input("Enter job", min_value=0, max_value=10, value=2)
housing= st.selectbox("Enter housing", ["Rent", "Own", "Free"])
saving_accounts= st.selectbox("Enter saving accounts", ["little", "moderate", "rich", "quite rich"])
checking_account= st.selectbox("Enter checking account", ["little", "moderate", "rich"])
credit_amount = st.number_input("Enter credit amount", min_value=0, value=1000)
duration = st.number_input("Enter duration(months)", min_value=1, value=12)
# Out:
# 2026-01-31 14:49:03.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:49:03.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:49:03.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:49:03.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:49:03.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:49:03.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:49:03.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
input_df = pd.DataFrame({
    "Age": [age],
    "Sex": [encoders['Sex'].transform([sex.lower()])[0]], # Convert to lowercase for potential case sensitivity
    "Job": [job],
    "Housing": [encoders['Housing'].transform([housing.lower()])[0]], # Convert to lowercase for potential case sensitivity
    "Saving accounts": [encoders['Saving accounts'].transform([saving_accounts.lower()])[0]], # Convert to lowercase for potential case sensitivity
    "Checking account": [encoders['Checking account'].transform([checking_account.lower()])[0]], # Convert to lowercase for potential case sensitivity
    "Credit amount": [credit_amount],
    "Duration": [duration]
})

# %%
if st.button('Predict Risk'):
  pred= model.predict(input_df)[0]
  if pred == 1:
    st.write("Predicted Credit Risk: **GOOD**")
  else:
    st.error('Predicted credit Risk: **BAD** ')
# Out:
# 2026-01-31 15:04:43.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 15:04:43.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 15:04:43.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 15:04:43.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 15:04:43.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 15:04:43.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ### 1. Save your Streamlit app code to a Python file (`app.py`)

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import joblib
from google.colab import drive

# Mount Google Drive to access model and encoders
drive.mount('/content/drive', force_remount=True)

# Load the pre-trained model
model = joblib.load("/content/drive/MyDrive/Colab Notebooks/extra_trees_credit_model.pkl")

# Load the label encoders
encoders = {col: joblib.load(f"/content/drive/MyDrive/Colab Notebooks/{col}_encoder.pkl")
    for col in ['Sex', 'Housing', 'Saving accounts', 'Checking account', 'Purpose']}

st.title("Credit Risk Prediction App")
st.write("Enter applicant information to predict credit risk")

# Input fields for user data
age = st.number_input("Enter age", min_value=18, max_value=100, value=30)
sex = st.selectbox("Enter sex", ["Male", "Female"])
job = st.number_input("Enter job", min_value=0, max_value=10, value=2)
housing = st.selectbox("Enter housing", ["Rent", "Own", "Free"])
saving_accounts = st.selectbox("Enter saving accounts", ["little", "moderate", "rich", "quite rich"])
checking_account = st.selectbox("Enter checking account", ["little", "moderate", "rich"])
credit_amount = st.number_input("Enter credit amount", min_value=0, value=1000)
duration = st.number_input("Enter duration (months)", min_value=1, value=12)

# Create a DataFrame from the input
input_df = pd.DataFrame({
    "Age": [age],
    "Sex": [encoders['Sex'].transform([sex.lower()])[0]],
    "Job": [job],
    "Housing": [encoders['Housing'].transform([housing.lower()])[0]],
    "Saving accounts": [encoders['Saving accounts'].transform([saving_accounts.lower()])[0]],
    "Checking account": [encoders['Checking account'].transform([checking_account.lower()])[0]],
    "Credit amount": [credit_amount],
    "Duration": [duration]
})

# Prediction button
if st.button('Predict Risk'):
    pred = model.predict(input_df)[0]
    if pred == 1:
        st.write("Predicted Credit Risk: **GOOD**")
    else:
        st.error('Predicted Credit Risk: **BAD** ')
# Out:
# Writing app.py

# %%
! pip install streamlit -q

# %%
! wget -q -O - ipv4.icanhazip.com
# Out:
# 34.26.83.139

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙⠹Usage: streamlit run [OPTIONS] [TARGET] [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: app.py
# ⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y)
